# %% [markdown]
# <a href="https://colab.research.google.com/github/durakmuhammetyasir/ProjectCampsJune/blob/main/VerilenDortSayiyiSirala_ipynb_adl%C4%B1_not_defterinin_kopyas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sayi1 = int(input("ilk sayiyi verin : "))
sayi2 = int(input("ikinci sayiyi verin : "))
sayi3 = int(input("ucuncu sayiyi verin : "))
sayi4 = int(input("dorduncu sayiyi verin : "))
if(sayi3==sayi4):    
  print(str(sayi3) + "=" + str(sayi4))
  if(sayi2==sayi3):    
    print(str(sayi2) + "=" + str(sayi3))
    print(str(sayi2) + "=" + str(sayi4))
    print(str(sayi2) + "=" + str(sayi3) + "=" + str(sayi4))
    if(sayi1==sayi2):    
      print(str(sayi1) + "=" + str(sayi2))
      print(str(sayi1) + "=" + str(sayi3))
      print(str(sayi1) + "=" + str(sayi4))
      print(str(sayi1) + "=" + str(sayi3) + "=" + str(sayi4))
      print(str(sayi1) + "=" + str(sayi2) + "=" + str(sayi4))
      print(str(sayi1) + "=" + str(sayi2) + "=" + str(sayi3))
      print(str(sayi1) + "=" + str(sayi2) + "=" + str(sayi3) + "=" + str(sayi4))
      #1=2=3=4
    elif(sayi1<sayi2):    
      print(str(sayi1) + "<" + str(sayi2))
      print(str(sayi1) + "=" + str(sayi3))
      print(str(sayi1) + "=" + str(sayi4))
      print(str(sayi1) + "=" + str(sayi3) + "=" + str(sayi4))
      print(str(sayi1) + "=" + str(sayi4) + "<" + str(sayi2))
      print(str(sayi1) + "=" + str(sayi3) + "<" + str(sayi2))
      print(str(sayi1) + "=" + str(sayi4) + "=" + str(sayi3) + "<" + str(sayi2))
      #2>1=3=4
    elif(sayi1>sayi2):    
      print(str(sayi2) + "<" + str(sayi1))
      print(str(sayi1) + "=" + str(sayi3))
      print(str(sayi1) + "=" + str(sayi4))
      print(str(sayi4) + "=" + str(sayi3) + "<" + str(sayi1))
      print(str(sayi4) + "=" + str(sayi2) + "<" + str(sayi1))
      print(str(sayi3) + "=" + str(sayi2) + "<" + str(sayi1))
      print(str(sayi4) + "=" + str(sayi2) + "=" + str(sayi3) + "<" + str(sayi1))
      #1>2=3=4
  elif(sayi2<sayi3):    
    print(str(sayi2) + "<" + str(sayi3))
    print(str(sayi2) + "<" + str(sayi4))    
    print(str(sayi2) + "<" + str(sayi3) + "=" + str(sayi4))
    if(sayi1==sayi2):    
      print(str(sayi1) + "=" + str(sayi2))
      print(str(sayi1) + "<" + str(sayi3))
      print(str(sayi1) + "<" + str(sayi4))
      print(str(sayi1) + "<" + str(sayi3) + "=" + str(sayi4))
      print(str(sayi1) + "=" + str(sayi2) + "<" + str(sayi4))
      print(str(sayi1) + "=" + str(sayi2) + "<" + str(sayi3))
      print(str(sayi1) + "=" + str(sayi2) + "<" + str(sayi3) + "=" + str(sayi4))
      #3=4>1=2
    elif(sayi1<sayi2):    
      print(str(sayi1) + "<" + str(sayi2))
      print(str(sayi1) + "<" + str(sayi3))
      print(str(sayi1) + "<" + str(sayi4))
      print(str(sayi1) + "<" + str(sayi3) + "=" + str(sayi4))
      print(str(sayi1) + "<" + str(sayi2) + "<" + str(sayi4))
      print(str(sayi1) + "<" + str(sayi2) + "<" + str(sayi3))
      print(str(sayi1) + "<" + str(sayi2) + "<" + str(sayi3) + "=" + str(sayi4))
      #3=4>2>1
    elif(sayi1>sayi2):    
      print(str(sayi2) + "<" + str(sayi1))
      if(sayi1==sayi3):    
        print(str(sayi1) + "=" + str(sayi3))
        print(str(sayi1) + "=" + str(sayi4))
        print(str(sayi1) + "=" + str(sayi3) + "=" + str(sayi4))
        print(str(sayi2) + "<" + str(sayi1) + "=" + str(sayi4))
        print(str(sayi2) + "<" + str(sayi1) + "=" + str(sayi3))
        print(str(sayi2) + "<" + str(sayi1) + "=" + str(sayi3) + "=" + str(sayi4))
        #1=3=4>2
      elif(sayi1<sayi3):    
        print(str(sayi1) + "<" + str(sayi3))
        print(str(sayi1) + "<" + str(sayi4))
        print(str(sayi1) + "<" + str(sayi3) + "=" + str(sayi4))
        print(str(sayi2) + "<" + str(sayi1) + "<" + str(sayi4))
        print(str(sayi2) + "<" + str(sayi1) + "<" + str(sayi3))
        print(str(sayi2) + "<" + str(sayi1) + "<" + str(sayi3) + "=" + str(sayi4))
        #4=3>1>2
      elif(sayi1>sayi3):    
        print(str(sayi3) + "<" + str(sayi1))
        print(str(sayi3) + "=" + str(sayi4))
        print(str(sayi4) + "=" + str(sayi3) + "=" + str(sayi1))
        print(str(sayi2) + "<" + str(sayi4) + "<" + str(sayi1))
        print(str(sayi2) + "<" + str(sayi3) + "<" + str(sayi1))
        print(str(sayi2) + "<" + str(sayi4) + "=" + str(sayi3) + "=" + str(sayi1))
        #1>3=4>2      
  elif(sayi2>sayi3):    
    print(str(sayi3) + "<" + str(sayi2))
    print(str(sayi4) + "<" + str(sayi2))
    print(str(sayi3) + "=" + str(sayi4) + "<" + str(sayi2))
    if(sayi1==sayi2):    
      print(str(sayi1) + "=" + str(sayi2))
      print(str(sayi3) + "<" + str(sayi1))
      print(str(sayi4) + "<" + str(sayi1))
      print(str(sayi4) + "=" + str(sayi3) + "<" + str(sayi1))
      print(str(sayi3) + "<" + str(sayi1) + "=" + str(sayi2))
      print(str(sayi4) + "<" + str(sayi2) + "=" + str(sayi1))
      print(str(sayi4) + "=" + str(sayi3) + "<" + str(sayi2) + "=" + str(sayi1))
      #1=2>3=4
    elif(sayi1<sayi2):    
      print(str(sayi1) + "<" + str(sayi2))
      if(sayi1==sayi3):    
        print(str(sayi1) + "=" + str(sayi3))
        print(str(sayi1) + "=" + str(sayi4))
        print(str(sayi1) + "=" + str(sayi4) + "=" + str(sayi3))
        print(str(sayi1) + "=" + str(sayi4) + "<" + str(sayi2))
        print(str(sayi1) + "=" + str(sayi3) + "<" + str(sayi2))
        print(str(sayi1) + "=" + str(sayi3) + "=" + str(sayi4) + "<" + str(sayi2))
        #2>1=3=4  
      elif(sayi1>sayi3):    
        print(str(sayi3) + "<" + str(sayi1))
        print(str(sayi4) + "<" + str(sayi1))
        print(str(sayi4) + "=" + str(sayi3) + "<" + str(sayi1))
        print(str(sayi4) + "<" + str(sayi1) + "<" + str(sayi2))
        print(str(sayi3) + "<" + str(sayi1) + "<" + str(sayi2))
        print(str(sayi4) + "=" + str(sayi3) + "<" + str(sayi1) + "<" + str(sayi2))
        #2>1>3=4    
      elif(sayi1<sayi3):    
        print(str(sayi1) + "<" + str(sayi3))
        print(str(sayi1) + "<" + str(sayi4))
        print(str(sayi1) + "<" + str(sayi4) + "=" + str(sayi3))
        print(str(sayi1) + "<" + str(sayi4) + "<" + str(sayi2))
        print(str(sayi1) + "<" + str(sayi3) + "<" + str(sayi2))
        print(str(sayi1) + "<" + str(sayi3) + "=" + str(sayi4) + "<" + str(sayi2))
        #2>3=4>1  
    elif(sayi1>sayi2):    
      print(str(sayi2) + "<" + str(sayi1))
      print(str(sayi3) + "<" + str(sayi1))
      print(str(sayi4) + "<" + str(sayi1))
      print(str(sayi4) + "=" + str(sayi3) + "<" + str(sayi1))
      print(str(sayi3) + "<" + str(sayi2) + "<" + str(sayi1))
      print(str(sayi4) + "<" + str(sayi2) + "<" + str(sayi1))
      print(str(sayi4) + "=" + str(sayi3) + "<" + str(sayi2) + "<" + str(sayi1))
      #1>2>3=4
elif(sayi3>sayi4):
  print(str(sayi4) + "<" + str(sayi3))
  if(sayi2==sayi3):
    print(str(sayi2) + "=" + str(sayi3))
    print(str(sayi4) + "<" + str(sayi2))
    print(str(sayi4) + "<" + str(sayi2) + "=" + str(sayi3))
    if(sayi1==sayi2):
      print(str(sayi2) + "=" + str(sayi1))
      print(str(sayi3) + "=" + str(sayi1))
      print(str(sayi4) + "<" + str(sayi1))
      print(str(sayi4) + "<" + str(sayi2) + "=" + str(sayi1))
      print(str(sayi4) + "<" + str(sayi1) + "=" + str(sayi3))
      print(str(sayi1) + "=" + str(sayi2) + "=" + str(sayi3))
      print(str(sayi4) + "<" + str(sayi2) + "=" + str(sayi3) + "=" + str(sayi1))
      #1=2=3>4
    elif(sayi1<sayi2):
      print(str(sayi1) + "<" + str(sayi2))
      print(str(sayi1) + "<" + str(sayi2) + "=" + str(sayi3))
      if(sayi1==sayi4):
        print(str(sayi1) + "=" + str(sayi4))
        print(str(sayi4) + "<" + str(sayi2))
        print(str(sayi1) + "<" + str(sayi3))
        print(str(sayi1) + "=" + str(sayi4) + "<" + str(sayi2))
        print(str(sayi1) + "=" + str(sayi4) + "<" + str(sayi3))
        print(str(sayi4) + "=" + str(sayi1) + "<" + str(sayi2) + "=" + str(sayi3))      
        #2=3>1=4
      elif(sayi1<sayi4):
        print(str(sayi1) + "<" + str(sayi4))
        print(str(sayi4) + "<" + str(sayi2))
        print(str(sayi1) + "<" + str(sayi3))
        print(str(sayi1) + "<" + str(sayi4) + "<" + str(sayi2))
        print(str(sayi1) + "<" + str(sayi4) + "<" + str(sayi3))
        print(str(sayi1) + "<" + str(sayi4) + "<" + str(sayi2) + "=" + str(sayi3))
        #2=3>4>1
      elif(sayi1>sayi4):
        print(str(sayi4) + "<" + str(sayi1))
        print(str(sayi4) + "<" + str(sayi2))
        print(str(sayi1) + "<" + str(sayi3))
        print(str(sayi4) + "<" + str(sayi1) + "<" + str(sayi2))
        print(str(sayi4) + "<" + str(sayi1) + "<" + str(sayi3))
        print(str(sayi4) + "<" + str(sayi1) + "<" + str(sayi2) + "=" + str(sayi3))
        #2=3>1>4
    elif(sayi1>sayi2):
      print(str(sayi2) + "<" + str(sayi1))
      print(str(sayi3) + "<" + str(sayi1))
      print(str(sayi4) + "<" + str(sayi1))
      print(str(sayi4) + "<" + str(sayi2) + "<" + str(sayi1))
      print(str(sayi4) + "<" + str(sayi3) + "<" + str(sayi1))
      print(str(sayi2) + "=" + str(sayi3) + "<" + str(sayi1))
      print(str(sayi4) + "<" + str(sayi2) + "=" + str(sayi3) + "<" + str(sayi1))
      #1>2=3>4
  elif(sayi2<sayi3):
    print(str(sayi2) + "<" + str(sayi3))
    if(sayi2==sayi4):
      print(str(sayi4) + "=" + str(sayi2))
      print(str(sayi2) + "=" + str(sayi4) + "<" + str(sayi3))
      if(sayi1==sayi2):
        print(str(sayi2) + "=" + str(sayi1))
        print(str(sayi1) + "<" + str(sayi3))
        print(str(sayi1) + "=" + str(sayi4))
        print(str(sayi4) + "=" + str(sayi2) + "<" + str(sayi3))
        print(str(sayi4) + "=" + str(sayi1) + "<" + str(sayi3))
        print(str(sayi1) + "=" + str(sayi2) + "<" + str(sayi3))
        print(str(sayi1) + "=" + str(sayi2) + "=" + str(sayi4) + "<" + str(sayi3))
        #3>1=2=4
      elif(sayi1<sayi2):
        print(str(sayi1) + "<" + str(sayi2))
        print(str(sayi1) + "<" + str(sayi3))
        print(str(sayi1) + "=" + str(sayi4))
        print(str(sayi4) + "=" + str(sayi2) + "<" + str(sayi3))
        print(str(sayi1) + "<" + str(sayi4) + "<" + str(sayi3))
        print(str(sayi1) + "<" + str(sayi2) + "<" + str(sayi3))
        print(str(sayi1) + "<" + str(sayi2) + "=" + str(sayi4) + "<" + str(sayi3))
        #3>4=2>1
      elif(sayi1>sayi2):
        print(str(sayi2) + "<" + str(sayi1))
        print(str(sayi4) + "<" + str(sayi1))
        print(str(sayi2) + "=" + str(sayi4) + "<" + str(sayi3))
        print(str(sayi2) + "=" + str(sayi4) + "<" + str(sayi1))
        if(sayi1==sayi3):
          print(str(sayi1) + "=" + str(sayi3))          
          print(str(sayi4) + "<" + str(sayi1) + "=" + str(sayi3))
          print(str(sayi2) + "<" + str(sayi1) + "=" + str(sayi3))
          print(str(sayi4) + "=" + str(sayi2) + "<" + str(sayi1) + "=" + str(sayi3))
          #1=3>2=4
        elif(sayi1>sayi3):
          print(str(sayi3) + "<" + str(sayi1))          
          print(str(sayi4) + "<" + str(sayi3) + "<" + str(sayi1))
          print(str(sayi2) + "<" + str(sayi3) + "<" + str(sayi1))
          print(str(sayi4) + "=" + str(sayi2) + "<" + str(sayi3) + "=" + str(sayi1))
          #1>3>2=4
        elif(sayi1<sayi3):
          print(str(sayi1) + "<" + str(sayi3))          
          print(str(sayi4) + "<" + str(sayi1) + "<" + str(sayi3))
          print(str(sayi2) + "<" + str(sayi1) + "<" + str(sayi3))
          print(str(sayi4) + "=" + str(sayi2) + "<" + str(sayi1) + "<" + str(sayi3))
          #3>1>2=4
    elif(sayi2>sayi4):
      print(str(sayi4) + "<" + str(sayi2))
      print(str(sayi4) + "<" + str(sayi2) + "<" + str(sayi3))
      if(sayi1==sayi2):
        print(str(sayi1) + "=" + str(sayi2))
        print(str(sayi1) + "<" + str(sayi3))
        print(str(sayi4) + "<" + str(sayi1))
        print(str(sayi4) + "<" + str(sayi1) + "<" + str(sayi3))
        print(str(sayi2) + "=" + str(sayi1) + "<" + str(sayi3))
        print(str(sayi4) + "<" + str(sayi1) + "=" + str(sayi2))
        print(str(sayi4) + "<" + str(sayi1) + "=" + str(sayi2) + "<" + str(sayi3))
        #3>1=2>4
      elif(sayi1<sayi2):
        print(str(sayi1) + "<" + str(sayi2))
        print(str(sayi1) + "<" + str(sayi3))
        if(sayi1==sayi4):
          print(str(sayi1) + "=" + str(sayi4))
          print(str(sayi1) + "=" + str(sayi4) + "<" + str(sayi3))
          print(str(sayi1) + "<" + str(sayi2) + "<" + str(sayi3))
          print(str(sayi4) + "<" + str(sayi2) + "<" + str(sayi3))
          print(str(sayi4) + "=" + str(sayi1) + "<" + str(sayi2) + "<" + str(sayi3))
          #3>2>1=4
        elif(sayi1<sayi4):
          print(str(sayi1) + "<" + str(sayi4))
          print(str(sayi1) + "<" + str(sayi4) + "<" + str(sayi3))
          print(str(sayi1) + "<" + str(sayi2) + "<" + str(sayi3))
          print(str(sayi4) + "<" + str(sayi2) + "<" + str(sayi3))
          print(str(sayi4) + "<" + str(sayi1) + "<" + str(sayi2) + "<" + str(sayi3))
          #3>2>4>1
        elif(sayi1>sayi4):
          print(str(sayi4) + "<" + str(sayi1))
          print(str(sayi4) + "<" + str(sayi1) + "<" + str(sayi3))
          print(str(sayi1) + "<" + str(sayi2) + "<" + str(sayi3))
          print(str(sayi4) + "<" + str(sayi2) + "<" + str(sayi3))
          print(str(sayi4) + "<" + str(sayi1) + "<" + str(sayi2) + "<" + str(sayi3))
          #3>2>1>4
      elif(sayi1>sayi2):
        print(str(sayi2) + "<" + str(sayi1))
        print(str(sayi4) + "<" + str(sayi1))
        print(str(sayi4) + "<" + str(sayi2) + "<" + str(sayi1))        
        if(sayi1==sayi3):
          print(str(sayi1) + "=" + str(sayi3))
          print(str(sayi4) + "<" + str(sayi1) + "=" + str(sayi3))
          print(str(sayi2) + "<" + str(sayi1) + "=" + str(sayi3))
          print(str(sayi4) + "<" + str(sayi2) + "<" + str(sayi1) + "=" + str(sayi3))
          #3=1>2>4
        elif(sayi1<sayi3):
          print(str(sayi1) + "<" + str(sayi3))
          print(str(sayi4) + "<" + str(sayi1) + "<" + str(sayi3))
          print(str(sayi2) + "<" + str(sayi1) + "<" + str(sayi3))
          print(str(sayi4) + "<" + str(sayi2) + "<" + str(sayi1) + "<" + str(sayi3))
          #3>1>2>4
        elif(sayi1>sayi3):
          print(str(sayi3) + "<" + str(sayi1))
          print(str(sayi4) + "<" + str(sayi3) + "<" + str(sayi1))
          print(str(sayi2) + "<" + str(sayi3) + "<" + str(sayi1))
          print(str(sayi4) + "<" + str(sayi2) + "<" + str(sayi3) + "<" + str(sayi1))
          #1>3>2>4
    elif(sayi2<sayi4):
      print(str(sayi2) + "<" + str(sayi4))
      print(str(sayi2) + "<" + str(sayi3))
      print(str(sayi2) + "<" + str(sayi4) + "<" + str(sayi3))
      if(sayi1==sayi2):
        print(str(sayi1) + "=" + str(sayi2))
        print(str(sayi1) + "<" + str(sayi3))
        print(str(sayi1) + "<" + str(sayi4))
        print(str(sayi1) + "<" + str(sayi4) + "<" + str(sayi3))
        print(str(sayi1) + "=" + str(sayi2) + "<" + str(sayi3))
        print(str(sayi1) + "=" + str(sayi2) + "<" + str(sayi4))
        print(str(sayi1) + "=" + str(sayi2) + "<" + str(sayi4) + "<" + str(sayi3))
        #3>4>1=2
      elif(sayi1<sayi2):
        print(str(sayi1) + "<" + str(sayi2))
        print(str(sayi1) + "<" + str(sayi3))
        print(str(sayi1) + "<" + str(sayi4))
        print(str(sayi1) + "<" + str(sayi4) + "<" + str(sayi3))
        print(str(sayi1) + "=" + str(sayi2) + "<" + str(sayi3))
        print(str(sayi1) + "=" + str(sayi2) + "<" + str(sayi4))
        print(str(sayi1) + "=" + str(sayi2) + "<" + str(sayi4) + "<" + str(sayi3))
        #3>4>2>1
      elif(sayi1>sayi2):
        print(str(sayi2) + "<" + str(sayi1))
        if(sayi1==sayi3):
          print(str(sayi1) + "=" + str(sayi3))
          print(str(sayi4) + "<" + str(sayi1))
          print(str(sayi2) + "<" + str(sayi1) + "=" + str(sayi3))
          print(str(sayi4) + "<" + str(sayi1) + "=" + str(sayi3))
          print(str(sayi2) + "<" + str(sayi4) + "<" + str(sayi1))
          print(str(sayi2) + "<" + str(sayi4) + "<" + str(sayi1) + "=" + str(sayi3))
          #3=1>4>2
        elif(sayi1>sayi3):
          print(str(sayi3) + "<" + str(sayi1))
          print(str(sayi4) + "<" + str(sayi1))
          print(str(sayi2) + "<" + str(sayi3) + "<" + str(sayi1))
          print(str(sayi4) + "<" + str(sayi3) + "<" + str(sayi1))
          print(str(sayi2) + "<" + str(sayi4) + "<" + str(sayi1))
          print(str(sayi2) + "<" + str(sayi4) + "<" + str(sayi3) + "<" + str(sayi1))
          #1>3>4>2
        elif(sayi1<sayi3):
          print(str(sayi1) + "<" + str(sayi3))
          print(str(sayi2) + "<" + str(sayi1) + "<" + str(sayi3))
          if(sayi1==sayi4):
            print(str(sayi4) + "=" + str(sayi1))
            print(str(sayi4) + "=" + str(sayi1) + "<" + str(sayi3))
            print(str(sayi2) + "<" + str(sayi4) + "=" + str(sayi1))
            print(str(sayi2) + "<" + str(sayi4) + "=" + str(sayi1) + "<" + str(sayi3))
            #3>1=4>2
          elif(sayi1<sayi4):
            print(str(sayi1) + "<" + str(sayi4))
            print(str(sayi2) + "<" + str(sayi1) + "<" + str(sayi3))
            print(str(sayi2) + "<" + str(sayi1) + "<" + str(sayi4))
            print(str(sayi2) + "<" + str(sayi1) + "<" + str(sayi4) + "<" + str(sayi3))
            #3>4>1>2
          elif(sayi1>sayi4):
            print(str(sayi4) + "<" + str(sayi1))
            print(str(sayi4) + "<" + str(sayi1) + "<" + str(sayi3))
            print(str(sayi2) + "<" + str(sayi4) + "<" + str(sayi1))
            print(str(sayi2) + "<" + str(sayi4) + "<" + str(sayi1) + "<" + str(sayi3))
            #3>1>4>2
  elif(sayi2>sayi3):
    print(str(sayi3) + "<" + str(sayi2))
    print(str(sayi4) + "<" + str(sayi2))
    print(str(sayi4) + "<" + str(sayi3) + "<" + str(sayi2))
    if(sayi1==sayi2):
      print(str(sayi1) + "=" + str(sayi2))
      print(str(sayi3) + "<" + str(sayi1))
      print(str(sayi4) + "<" + str(sayi1))      
      print(str(sayi4) + "<" + str(sayi2) + "=" + str(sayi1))
      print(str(sayi4) + "<" + str(sayi3) + "<" + str(sayi1))
      print(str(sayi4) + "<" + str(sayi3) + "<" + str(sayi2) + "=" + str(sayi1))
      #1=2>3>4
    elif(sayi1<sayi2):
      print(str(sayi1) + "<" + str(sayi2))
      if(sayi1==sayi3):
        print(str(sayi1) + "=" + str(sayi3))
        print(str(sayi4) + "<" + str(sayi1))
        print(str(sayi1) + "=" + str(sayi3) + "<" + str(sayi2))
        print(str(sayi4) + "<" + str(sayi3) + "=" + str(sayi1))
        print(str(sayi4) + "<" + str(sayi3) + "=" + str(sayi1) + "<" + str(sayi2))
        #2>1=3>4
      elif(sayi1<sayi3):
        print(str(sayi1) + "<" + str(sayi3))
        print(str(sayi1) + "<" + str(sayi3) + "<" + str(sayi2))
        if(sayi1==sayi4):
          print(str(sayi1) + "=" + str(sayi4))          
          print(str(sayi4) + "=" + str(sayi1) + "<" + str(sayi3))
          print(str(sayi1) + "<" + str(sayi3) + "<" + str(sayi2))
          print(str(sayi4) + "=" + str(sayi1) + "<" + str(sayi3) + "<" + str(sayi2))
          #2>3>1=4
        elif(sayi1>sayi4):
          print(str(sayi4) + "<" + str(sayi1))          
          print(str(sayi4) + "<" + str(sayi1) + "<" + str(sayi3))
          print(str(sayi1) + "<" + str(sayi3) + "<" + str(sayi2))
          print(str(sayi4) + "<" + str(sayi1) + "<" + str(sayi3) + "<" + str(sayi2))
          #2>3>1>4
        elif(sayi1<sayi4):
          print(str(sayi1) + "<" + str(sayi4))          
          print(str(sayi1) + "<" + str(sayi4) + "<" + str(sayi3))
          print(str(sayi1) + "<" + str(sayi3) + "<" + str(sayi2))
          print(str(sayi1) + "<" + str(sayi4) + "<" + str(sayi3) + "<" + str(sayi2))
          #2>3>4>1
      elif(sayi1>sayi3):
        print(str(sayi3) + "<" + str(sayi1))
        print(str(sayi4) + "<" + str(sayi1))
        print(str(sayi3) + "<" + str(sayi1) + "<" + str(sayi2))
        print(str(sayi4) + "<" + str(sayi3) + "<" + str(sayi1))
        print(str(sayi4) + "<" + str(sayi3) + "<" + str(sayi1) + "<" + str(sayi2))
        #2>1>3>4
    elif(sayi1>sayi2):
      print(str(sayi2) + "<" + str(sayi1))
      print(str(sayi3) + "<" + str(sayi1))
      print(str(sayi4) + "<" + str(sayi1))
      print(str(sayi3) + "<" + str(sayi2) + "<" + str(sayi1))
      print(str(sayi4) + "<" + str(sayi2) + "<" + str(sayi1))
      print(str(sayi4) + "<" + str(sayi3) + "<" + str(sayi1))
      print(str(sayi4) + "<" + str(sayi3) + "<" + str(sayi2) + "<" + str(sayi1))
      #1>2>3>4
elif(sayi3<sayi4):
  print(str(sayi3) + "<" + str(sayi4))
  if(sayi2==sayi3):
    print(str(sayi2) + "=" + str(sayi3))
    print(str(sayi2) + "<" + str(sayi4))
    print(str(sayi2) + "=" + str(sayi3) + "<" + str(sayi4))
    if(sayi1==sayi2):
      print(str(sayi1) + "=" + str(sayi2))
      print(str(sayi1) + "=" + str(sayi3))
      print(str(sayi1) + "<" + str(sayi4))
      print(str(sayi1) + "=" + str(sayi2) + "=" + str(sayi3))
      print(str(sayi1) + "=" + str(sayi3) + "<" + str(sayi4))
      print(str(sayi1) + "=" + str(sayi2) + "<" + str(sayi4))
      print(str(sayi1) + "=" + str(sayi2) + "=" + str(sayi3) + "<" + str(sayi4))
      #4>1=2=3
    elif(sayi1<sayi2):
      print(str(sayi1) + "<" + str(sayi2))
      print(str(sayi1) + "<" + str(sayi3))
      print(str(sayi1) + "<" + str(sayi4))
      print(str(sayi1) + "<" + str(sayi2) + "=" + str(sayi3))
      print(str(sayi1) + "<" + str(sayi3) + "<" + str(sayi4))
      print(str(sayi1) + "<" + str(sayi2) + "<" + str(sayi4))
      print(str(sayi1) + "<" + str(sayi2) + "=" + str(sayi3) + "<" + str(sayi4))
      #4>3=2>1 
    elif(sayi1>sayi2):
      print(str(sayi2) + "<" + str(sayi1))
      print(str(sayi3) + "<" + str(sayi1))
      if(sayi1==sayi4):
        print(str(sayi1) + "=" + str(sayi4))
        print(str(sayi3) + "<" + str(sayi4))
        print(str(sayi2) + "<" + str(sayi4))
        print(str(sayi3) + "<" + str(sayi1) + "=" + str(sayi4))
        print(str(sayi2) + "<" + str(sayi1) + "=" + str(sayi4))
        print(str(sayi2) + "=" + str(sayi3) + "<" + str(sayi4))
        print(str(sayi2) + "=" + str(sayi3) + "<" + str(sayi4) + "=" + str(sayi1))
        #1=4>2=3
      elif(sayi1<sayi4):
        print(str(sayi1) + "<" + str(sayi4))
        print(str(sayi3) + "<" + str(sayi4))
        print(str(sayi2) + "<" + str(sayi4))
        print(str(sayi3) + "<" + str(sayi1) + "<" + str(sayi4))
        print(str(sayi2) + "<" + str(sayi1) + "<" + str(sayi4))
        print(str(sayi2) + "=" + str(sayi3) + "<" + str(sayi4))
        print(str(sayi2) + "=" + str(sayi3) + "<" + str(sayi1) + "<" + str(sayi4))
        #4>1>2=3
      elif(sayi1>sayi4):
        print(str(sayi4) + "<" + str(sayi1))
        print(str(sayi3) + "<" + str(sayi4))
        print(str(sayi2) + "<" + str(sayi4))
        print(str(sayi3) + "<" + str(sayi4) + "<" + str(sayi1))
        print(str(sayi2) + "<" + str(sayi4) + "<" + str(sayi1))
        print(str(sayi2) + "=" + str(sayi3) + "<" + str(sayi4))
        print(str(sayi2) + "=" + str(sayi3) + "<" + str(sayi4) + "<" + str(sayi1))
        #1>4>2=3
  elif(sayi2<sayi3):
    print(str(sayi2) + "<" + str(sayi3))
    print(str(sayi2) + "<" + str(sayi4))
    print(str(sayi2) + "<" + str(sayi3) + "<" + str(sayi4))
    if(sayi1==sayi2):
      print(str(sayi1) + "=" + str(sayi2))
      print(str(sayi1) + "<" + str(sayi3))
      print(str(sayi1) + "<" + str(sayi4))
      print(str(sayi1) + "<" + str(sayi3) + "<" + str(sayi4))
      print(str(sayi1) + "=" + str(sayi2) + "<" + str(sayi4))
      print(str(sayi1) + "=" + str(sayi2) + "<" + str(sayi3))
      print(str(sayi1) + "=" + str(sayi2) + "<" + str(sayi3) + "<" + str(sayi4))
      #4>3>2=1
    elif(sayi1<sayi2):
      print(str(sayi1) + "<" + str(sayi2))
      print(str(sayi1) + "<" + str(sayi3))
      print(str(sayi1) + "<" + str(sayi4))
      print(str(sayi1) + "<" + str(sayi3) + "<" + str(sayi4))
      print(str(sayi1) + "<" + str(sayi2) + "<" + str(sayi4))
      print(str(sayi1) + "<" + str(sayi2) + "<" + str(sayi3))
      print(str(sayi1) + "<" + str(sayi2) + "<" + str(sayi3) + "<" + str(sayi4))
      #4>3>2>1
    elif(sayi1>sayi2):
      print(str(sayi2) + "<" + str(sayi1))
      if(sayi1 == sayi3):
        print(str(sayi1) + "=" + str(sayi3))
        print(str(sayi1) + "<" + str(sayi4))
        print(str(sayi2) + "<" + str(sayi3) + "<" + str(sayi4))
        print(str(sayi2) + "<" + str(sayi1) + "<" + str(sayi4))
        print(str(sayi2) + "<" + str(sayi1) + "=" + str(sayi3))
        print(str(sayi2) + "<" + str(sayi1) + "=" + str(sayi3) + "<" + str(sayi4))
        #4>3=1>2
      elif(sayi1 < sayi3):
        print(str(sayi1) + "<" + str(sayi3))
        print(str(sayi1) + "<" + str(sayi4))
        print(str(sayi2) + "<" + str(sayi3) + "<" + str(sayi4))
        print(str(sayi2) + "<" + str(sayi1) + "<" + str(sayi4))
        print(str(sayi2) + "<" + str(sayi1) + "<" + str(sayi3))
        print(str(sayi2) + "<" + str(sayi1) + "<" + str(sayi3) + "<" + str(sayi4))
        #4>3>1>2
      elif(sayi1 > sayi3):
        print(str(sayi3) + "<" + str(sayi1))
        if(sayi1==sayi4):
          print(str(sayi1) + "=" + str(sayi4))
          print(str(sayi2) + "<" + str(sayi3) + "<" + str(sayi4))
          print(str(sayi2) + "<" + str(sayi1) + "=" + str(sayi4))
          print(str(sayi2) + "<" + str(sayi3) + "<" + str(sayi1))
          print(str(sayi2) + "<" + str(sayi3) + "<" + str(sayi1) + "=" + str(sayi4))
          #4=1>3>2
        elif(sayi1<sayi4):
          print(str(sayi1) + "<" + str(sayi4))
          print(str(sayi2) + "<" + str(sayi3) + "<" + str(sayi4))
          print(str(sayi2) + "<" + str(sayi1) + "<" + str(sayi4))
          print(str(sayi2) + "<" + str(sayi3) + "<" + str(sayi1))
          print(str(sayi2) + "<" + str(sayi3) + "<" + str(sayi1) + "<" + str(sayi4))
          #4>1>3>2
        elif(sayi1>sayi4):
          print(str(sayi4) + "<" + str(sayi1))
          print(str(sayi2) + "<" + str(sayi3) + "<" + str(sayi4))
          print(str(sayi2) + "<" + str(sayi4) + "<" + str(sayi1))
          print(str(sayi2) + "<" + str(sayi3) + "<" + str(sayi1))
          print(str(sayi2) + "<" + str(sayi3) + "<" + str(sayi4) + "<" + str(sayi1))
          #1>4>3>2

  elif(sayi2>sayi3):
    print(str(sayi3) + "<" + str(sayi2))
    if(sayi2==sayi4):
      print(str(sayi4) + "=" + str(sayi2))
      print(str(sayi3) + "<" + str(sayi2) + "=" + str(sayi4))
      if(sayi1==sayi2):
        print(str(sayi1) + "=" + str(sayi2))
        print(str(sayi1) + "=" + str(sayi4))
        print(str(sayi3) + "<" + str(sayi1))
        print(str(sayi3) + "<" + str(sayi1) + "=" + str(sayi4))
        print(str(sayi3) + "<" + str(sayi2) + "=" + str(sayi1))
        print(str(sayi1) + "=" + str(sayi2) + "=" + str(sayi4))
        print(str(sayi3) + "<" + str(sayi1) + "=" + str(sayi2) + "=" + str(sayi4))
        #4=2=1>3
      elif(sayi1<sayi2):
        print(str(sayi1) + "<" + str(sayi2))
        if(sayi1==sayi3):
          print(str(sayi1) + "=" + str(sayi3))
          print(str(sayi1) + "<" + str(sayi4))
          print(str(sayi3) + "<" + str(sayi2) + "=" + str(sayi4))
          print(str(sayi1) + "<" + str(sayi2) + "=" + str(sayi4))
          print(str(sayi1) + "=" + str(sayi3) + "<" + str(sayi4))
          print(str(sayi1) + "=" + str(sayi3) + "<" + str(sayi2))
          print(str(sayi3) + "=" + str(sayi1) + "<" + str(sayi2) + "=" + str(sayi4))
          #2=4>3=1
        elif(sayi1<sayi3):
          print(str(sayi1) + "<" + str(sayi3))
          print(str(sayi1) + "<" + str(sayi4))
          print(str(sayi3) + "<" + str(sayi2) + "=" + str(sayi4))
          print(str(sayi1) + "<" + str(sayi2) + "=" + str(sayi4))
          print(str(sayi1) + "<" + str(sayi3) + "<" + str(sayi4))
          print(str(sayi1) + "<" + str(sayi3) + "<" + str(sayi2))
          print(str(sayi1) + "<" + str(sayi3) + "<" + str(sayi2) + "=" + str(sayi4))
          #2=4>3>1
        elif(sayi1>sayi3):
          print(str(sayi3) + "<" + str(sayi1))
          print(str(sayi1) + "<" + str(sayi4))
          print(str(sayi3) + "<" + str(sayi2) + "=" + str(sayi4))
          print(str(sayi1) + "<" + str(sayi2) + "=" + str(sayi4))
          print(str(sayi3) + "<" + str(sayi1) + "<" + str(sayi4))
          print(str(sayi3) + "<" + str(sayi1) + "<" + str(sayi2))
          print(str(sayi3) + "<" + str(sayi1) + "<" + str(sayi2) + "=" + str(sayi4))
          #2=4>1>3
      elif(sayi1>sayi2):
        print(str(sayi2) + "<" + str(sayi1))
        print(str(sayi3) + "<" + str(sayi4) + "=" + str(sayi2))
        print(str(sayi4) + "=" + str(sayi2) + "<" + str(sayi1))
        print(str(sayi3) + "<" + str(sayi4) + "<" + str(sayi1))
        print(str(sayi3) + "<" + str(sayi2) + "<" + str(sayi1))
        print(str(sayi3) + "<" + str(sayi4) + "=" + str(sayi2) + "<" + str(sayi1))
        #1>2=4>3
    elif(sayi2>sayi4):
      print(str(sayi4) + "<" + str(sayi2))
      print(str(sayi3) + "<" + str(sayi2))
      print(str(sayi3) + "<" + str(sayi4) + "<" + str(sayi2))
      if(sayi1==sayi2):
        print(str(sayi1) + "=" + str(sayi2))
        print(str(sayi4) + "<" + str(sayi1))
        print(str(sayi3) + "<" + str(sayi1))
        print(str(sayi3) + "<" + str(sayi4) + "<" + str(sayi1))
        print(str(sayi3) + "<" + str(sayi1) + "=" + str(sayi2))
        print(str(sayi4) + "<" + str(sayi1) + "=" + str(sayi2))
        print(str(sayi3) + "<" + str(sayi4) + "<" + str(sayi1) + "=" + str(sayi2))
        #2=1>4>3
      elif(sayi1<sayi2):
        print(str(sayi1) + "<" + str(sayi2))
        if(sayi1==sayi3):
          print(str(sayi1) + "=" + str(sayi3))
          print(str(sayi1) + "<" + str(sayi4))
          print(str(sayi1) + "=" + str(sayi3) + "<" + str(sayi4))            
          print(str(sayi3) + "=" + str(sayi1) + "<" + str(sayi2))
          print(str(sayi1) + "<" + str(sayi4) + "<" + str(sayi2))
          print(str(sayi1) + "=" + str(sayi3) + "<" + str(sayi4) + "<" + str(sayi2))
          #2>4>1=3
        elif(sayi1<sayi3):
          print(str(sayi1) + "<" + str(sayi3))
          print(str(sayi1) + "<" + str(sayi4))
          print(str(sayi1) + "<" + str(sayi3) + "<" + str(sayi4))            
          print(str(sayi3) + "<" + str(sayi4) + "<" + str(sayi2))
          print(str(sayi1) + "<" + str(sayi4) + "<" + str(sayi2))
          print(str(sayi1) + "<" + str(sayi3) + "<" + str(sayi4) + "<" + str(sayi2))
          #2>4>3>1
        elif(sayi1>sayi3):
          print(str(sayi3) + "<" + str(sayi1))
          print(str(sayi3) + "<" + str(sayi1) + "<" + str(sayi2))
          if(sayi1==sayi4):
            print(str(sayi4) + "=" + str(sayi1))
            print(str(sayi3) + "<" + str(sayi1) + "=" + str(sayi4))            
            print(str(sayi3) + "<" + str(sayi4) + "<" + str(sayi2))
            print(str(sayi1) + "=" + str(sayi4) + "<" + str(sayi2))
            print(str(sayi3) + "<" + str(sayi1) + "=" + str(sayi4) + "<" + str(sayi2))
            #2>4=1>3
          elif(sayi1>sayi4):
            print(str(sayi4) + "<" + str(sayi1))
            print(str(sayi3) + "<" + str(sayi4) + "<" + str(sayi1))            
            print(str(sayi3) + "<" + str(sayi4) + "<" + str(sayi2))
            print(str(sayi4) + "<" + str(sayi1) + "<" + str(sayi2))
            print(str(sayi3) + "<" + str(sayi4) + "<" + str(sayi1) + "<" + str(sayi2))
            #2>1>4>3
          elif(sayi1<sayi4):
            print(str(sayi1) + "<" + str(sayi4))
            print(str(sayi3) + "<" + str(sayi1) + "<" + str(sayi4))            
            print(str(sayi3) + "<" + str(sayi4) + "<" + str(sayi2))
            print(str(sayi1) + "<" + str(sayi4) + "<" + str(sayi2))
            print(str(sayi3) + "<" + str(sayi1) + "<" + str(sayi4) + "<" + str(sayi2))
            #2>4>1>3          
      elif(sayi1>sayi2):
        print(str(sayi2) + "<" + str(sayi1))
        print(str(sayi4) + "<" + str(sayi1))
        print(str(sayi3) + "<" + str(sayi1))
        print(str(sayi3) + "<" + str(sayi4) + "<" + str(sayi1))
        print(str(sayi3) + "<" + str(sayi2) + "<" + str(sayi1))
        print(str(sayi4) + "<" + str(sayi2) + "<" + str(sayi1))
        print(str(sayi3) + "<" + str(sayi4) + "<" + str(sayi2) + "<" + str(sayi1))
        #1>2>4>3
    elif(sayi2<sayi4):
      print(str(sayi2) + "<" + str(sayi4))
      print(str(sayi3) + "<" + str(sayi2) + "<" + str(sayi4))
      if(sayi1==sayi2):
        print(str(sayi2) + "=" + str(sayi1))
        print(str(sayi1) + "<" + str(sayi4))
        print(str(sayi3) + "<" + str(sayi1))
        print(str(sayi3) + "<" + str(sayi2) + "<" + str(sayi4))
        print(str(sayi3) + "<" + str(sayi1) + "<" + str(sayi4))
        print(str(sayi1) + "=" + str(sayi2) + "=" + str(sayi4))
        print(str(sayi3) + "<" + str(sayi2) + "=" + str(sayi1) + "=" + str(sayi4))
        #4>2=1>3
      elif(sayi1<sayi2):
        print(str(sayi1) + "<" + str(sayi2))
        print(str(sayi1) + "<" + str(sayi4))
        print(str(sayi1) + "<" + str(sayi2) + "<" + str(sayi4))
        if(sayi1==sayi3):
          print(str(sayi3) + "=" + str(sayi1))
          print(str(sayi1) + "=" + str(sayi3) + "<" + str(sayi4))
          print(str(sayi1) + "=" + str(sayi3) + "<" + str(sayi2))
          print(str(sayi1) + "=" + str(sayi3) + "<" + str(sayi2) + "<" + str(sayi4))
          #4>2>1=3
        elif(sayi1<sayi3):
          print(str(sayi1) + "<" + str(sayi3))
          print(str(sayi1) + "<" + str(sayi3) + "<" + str(sayi4))
          print(str(sayi1) + "<" + str(sayi3) + "<" + str(sayi2))
          print(str(sayi1) + "<" + str(sayi3) + "<" + str(sayi2) + "<" + str(sayi4))
          #4>2>3>1         
        elif(sayi1>sayi3):
          print(str(sayi3) + "<" + str(sayi1))
          print(str(sayi3) + "<" + str(sayi1) + "<" + str(sayi4))
          print(str(sayi3) + "<" + str(sayi1) + "<" + str(sayi2))
          print(str(sayi3) + "<" + str(sayi1) + "<" + str(sayi2) + "<" + str(sayi4))
          #4>2>1>3
      elif(sayi1>sayi2):
        print(str(sayi2) + "<" + str(sayi1))
        if(sayi1==sayi4):
          print(str(sayi1) + "=" + str(sayi4))
          print(str(sayi3) + "<" + str(sayi1))
          print(str(sayi3) + "<" + str(sayi2) + "<" + str(sayi4))
          print(str(sayi3) + "<" + str(sayi1) + "=" + str(sayi4))
          print(str(sayi2) + "<" + str(sayi1) + "=" + str(sayi4))
          print(str(sayi3) + "<" + str(sayi2) + "<" + str(sayi1) + "=" + str(sayi4))
          #4=1>2>3
        elif(sayi1<sayi4):
          print(str(sayi1) + "<" + str(sayi4))
          print(str(sayi3) + "<" + str(sayi1))
          print(str(sayi3) + "<" + str(sayi2) + "<" + str(sayi4))
          print(str(sayi3) + "<" + str(sayi1) + "<" + str(sayi4))
          print(str(sayi2) + "<" + str(sayi1) + "<" + str(sayi4))
          print(str(sayi3) + "<" + str(sayi2) + "<" + str(sayi1) + "<" + str(sayi4))
          #4>1>2>3
        elif(sayi1>sayi4):
          print(str(sayi4) + "<" + str(sayi1))
          print(str(sayi3) + "<" + str(sayi1))
          print(str(sayi3) + "<" + str(sayi2) + "<4" + str(sayi1))
          print(str(sayi3) + "<" + str(sayi4) + "<" + str(sayi1))
          print(str(sayi2) + "<" + str(sayi4) + "<" + str(sayi1))
          print(str(sayi3) + "<" + str(sayi2) + "<" + str(sayi4) + "<" + str(sayi1))
          #1>4>2>3
# Out:
# ilk sayiyi verin : 999
# ikinci sayiyi verin : 99
# ucuncu sayiyi verin : 99
# dorduncu sayiyi verin : 9
# 9<99
# 99=99
# 9<99
# 9<99=99
# 99<999
# 99<999
# 9<999
# 9<99<999
# 9<99<999
# 99=99<999
# 9<99=99<999
